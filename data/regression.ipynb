# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
diabetes_train = pd.read_csv('diabetes_train.csv').drop('Unnamed: 0', axis=1)
diabetes_train
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.012648  0.050680  0.002417  0.056301  0.027326  0.017162  0.041277
# 1   -0.107226 -0.044642 -0.077342 -0.026328 -0.089630 -0.096198  0.026550
# 2    0.027178  0.050680 -0.035307  0.032201 -0.011201  0.001504 -0.010266
# 3   -0.005515  0.050680  0.001339 -0.084856 -0.011201 -0.016658  0.048640
# 4    0.067136  0.050680  0.020739 -0.005670  0.020446  0.026243 -0.002903
# ..        ...       ...       ...       ...       ...       ...       ...
# 348  0.070769  0.050680 -0.007284  0.049415  0.060349 -0.004445 -0.054446
# 349  0.056239  0.050680 -0.030996  0.008101  0.019070  0.021233  0.033914
# 350  0.059871 -0.044642 -0.021295  0.087287  0.045213  0.031567 -0.047082
# 351 -0.078165 -0.044642 -0.073030 -0.057313 -0.084126 -0.074277 -0.024993
# 352  0.041708  0.050680  0.071397  0.008101  0.038334  0.015909 -0.017629
#
#            s4        s5        s6  target
# ...

# %%
X = diabetes_train.drop('target', axis=1)
y = diabetes_train['target']

# %%
lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# 152.5380470138517

# %%
lr.coef_
# Out:
# array([ -35.55025079, -243.16508959,  562.76234744,  305.46348218,
#        -662.70290089,  324.20738537,   24.74879489,  170.3249615 ,
#         731.63743545,   43.0309307 ])
